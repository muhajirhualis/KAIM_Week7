# %%
import sys
import os
from pathlib import Path

# Add project root to path so we can import from src/
project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

sys.path.append("../src")

from evaluation import run_systematic_evaluation
import pandas as pd

# %%
test_questions = [
    "What are common issues with credit cards?",
    "Why are customers unhappy with personal loans?",
    "What do customers say about mobile app performance?",
    "Are there complaints about failed money transfers?",
    "Do customers mention hidden fees in their accounts?"
]

# %%
# Run the evaluation
df = run_systematic_evaluation(test_questions)
# Out:
# Device set to use cpu
# Evaluating: What are common issues with credit cards?
# Token indices sequence length is longer than the specified maximum sequence length for this model (792 > 512). Running this sequence through the model will result in indexing errors
# Evaluating: Why are customers unhappy with personal loans?
# Evaluating: What do customers say about mobile app performance?
# Evaluating: Are there complaints about failed money transfers?
# Evaluating: Do customers mention hidden fees in their accounts?

# %%
# Save results for the Task 3 report
df.to_csv("../data/processed/rag_evaluation.csv", index=False)
display(df)
# Out:
#                                             Question  \
# 0          What are common issues with credit cards?
# 1     Why are customers unhappy with personal loans?
# 2  What do customers say about mobile app perform...
# 3  Are there complaints about failed money transf...
# 4  Do customers mention hidden fees in their acco...
#
#                                     Generated Answer Retrieved Sources  \
# 0  synchrony bank mastercard was alerted of the i...  ID: N/A, ID: N/A
# 1  they put pretty much all of my payment towards...  ID: N/A, ID: N/A
# 2  all was overdrawn! they cant continue to decei...  ID: N/A, ID: N/A
# 3                                                yes  ID: N/A, ID: N/A
# 4                                                 no  ID: N/A, ID: N/A
#
#   Quality Score (1-5) Comments
# 0
# 1
# 2
# 3
# 4
